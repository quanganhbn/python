# %% [markdown]
# <a href="https://colab.research.google.com/github/ikikika/python/blob/video_downloader/video_downloader/video_downloader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install m3u8
# Out:
# ...
#   Created wheel for m3u8: filename=m3u8-0.7.1-cp36-none-any.whl size=21872 sha256=5b5b7efe096640155b099c65aef9d748a523a08fc65137b79f947f41f9584ce4
#   Stored in directory: /root/.cache/pip/wheels/e4/dc/96/299917ff4dd3e3965e89fbf735c7bad401189a27783d66f40f
# Successfully built m3u8
# ...

# %%
import m3u8
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm_notebook as tqdm
import subprocess

# %%
sess = requests.Session()

# %%
r = sess.get("https://www.udemy.com/assets/5329782/files/637930/5329782/2016-02-20_21-10-00-cc1f53c5aa652135fbe541226345ec57/1/aa006f2c0695c6827edfd7fd8391650cac6b.m3u8?provider=verizon&v=1")

# %%
r = requests.get(url)

# %%
soup = BeautifulSoup(r.content, 'html5lib')

# %%
video_id = soup.find('video', attrs={'id': 'playlistPlayer'})['data-video-id']
account_id = soup.find('video', attrs={'id': 'playlistPlayer'})['data-account']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-c822a8fa5e99> in <module>()
# ----> 1 video_id = soup.find('video', attrs={'id': 'playlistPlayer'})['data-video-id']
#       2 account_id = soup.find('video', attrs={'id': 'playlistPlayer'})['data-account']
#
# TypeError: 'NoneType' object is not subscriptable

# %%
playlist_url = m3u8_master.data['playlists'][0]['uri']

# %%
r = requests.get(playlist_url)

# %%
playlist = m3u8.loads(r.text)

# %%
playlist.data
# Out:
# {'allow_cache': 'yes',
#  'iframe_playlists': [],
#  'is_endlist': True,
#  'is_i_frames_only': False,
#  'is_independent_segments': False,
#  'is_variant': False,
#  'keys': [None],
#  'media': [],
#  'media_sequence': 0,
#  'part_inf': {},
#  'playlist_type': None,
#  'playlists': [],
#  'rendition_reports': [],
#  'segments': [{'cue_in': False,
#    'cue_out': False,
#    'cue_out_start': False,
#    'dateranges': None,
#    'discontinuity': False,
#    'duration': 6.105378,
#    'gap_tag': None,
#    'title': '',
#    'uri': 'https://hls-a.udemycdn.com/637930/5329782/2016-02-20_21-10-00-cc1f53c5aa652135fbe541226345ec57/1/hls/AVC_640x360_90k_AAC-HE_64k/aa006f2c0695c6827edfd7fd8391650cac6b0.ts?3OvfsG9qHTQ7mVBahnuDGGpzKOzlF7JC4cg29uuQhsu4hgCkbZMFalwjcb041tOReAgaUwLc3TFQHo5T3wSrSgRjFxKudZgOa9gQ7l2U2TKKm1-xB1BTWa8OMvqT3LDLBIZd99hAzBw4GTqnWKrVqc0pF8d3EmxCmXRi16SD1qgR0Cd9RXpGnRN2jowBk42E_TDC9WolBOJKx-5J1fvYnZE2kk3HPr-TD88Jm4cuszHXQfPTvXSJHGShCkkW2A87ynaaGxG6GWFM55Fq'},
# ...
